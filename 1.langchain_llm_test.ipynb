# %%
# %pip install langchain-openai python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv();

updstage_api_key = os.getenv("UPSTAGE_API_KEY")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
llm.invoke("인프런에 어떤 강의가 있나요").content
# Out:
# '인프런에서는 다양한 주제의 강의가 제공되고 있습니다. 프로그래밍, 웹 개발, 데이터 분석, 디자인, 비즈니스, 취미 등 다양한 분야의 강의가 있어서 사용자들이 자신에게 맞는 강의를 선택할 수 있습니다. 또한 유명 강사들이 진행하는 강의도 많이 제공되어 있어서 높은 퀄리티의 강의를 수강할 수 있습니다. 원하는 분야나 키워드를 검색하면 관련된 강의를 쉽게 찾을 수 있습니다. 현재도 계속해서 새로운 강의가 올라옵니다. 인프런에서는 사용자들이 자기 개발 및 학습에 도움을 주기 위해 다양한 형태의 강의를 제공하고 있습니다.'
